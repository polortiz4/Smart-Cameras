# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(-np.pi,np.pi,200)
plt.plot(x,np.sin(x))

# %%
mpl.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
x=np.linspace(-np.pi,np.pi,200)
plt.plot(x,np.sin(x))

# %%
import imageio
from skimage import filters

# %%
im= imageio.imread('/Users/dbrad/OneDrive/Pictures/fairfiew5k.jpg')

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.imshow(im)

# %%
im.shape
# Out:
# (960, 720, 3)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.imshow(im[:,:,0], cmap='gray')

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.imshow(im[:,:,0]-im[:,:,2], cmap='gray')

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.imshow(im[:,:,1]-im[:,:,2], cmap='gray')

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.plot(im[100,:,1])

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.plot(im[300,:,1])

# %%
mpl.rcParams['figure.figsize'] = (30, 30) 
plt.plot(im[400,:,1])
